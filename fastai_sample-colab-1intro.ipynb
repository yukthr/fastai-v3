# %% [markdown]
# <a href="https://colab.research.google.com/github/yukthr/fastai-v3/blob/master/fastai_sample-colab-1intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq fastbook
# Out:
#      |████████████████████████████████| 720 kB 8.1 MB/s
#      |████████████████████████████████| 1.2 MB 81.8 MB/s
#      |████████████████████████████████| 46 kB 5.3 MB/s
#      |████████████████████████████████| 189 kB 71.7 MB/s
#      |████████████████████████████████| 56 kB 5.8 MB/s
#      |████████████████████████████████| 51 kB 293 kB/s

# %%
import fastbook

# %%
fastbook.setup_book()
# Out:
# Mounted at /content/gdrive

# %%
from fastbook import *

# %%
from fastai.vision.all import * 
path = untar_data(URLs.PETS)/'images'
# !dir(path)

def is_cat(x): return x[0].isupper()

dls = ImageDataLoaders.from_name_func(path, get_image_files(path), valid_pct=0.2, seed=42, label_func=is_cat, item_tfms=Resize(224))
learn = cnn_learner(dls, resnet34, metrics=error_rate)
learn.fine_tune(1)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `path'
# /bin/bash: -c: line 0: `dir(path)'
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.169917</td>
#       <td>0.024962</td>
#       <td>0.006089</td>
#       <td>00:27</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.053375</td>
#       <td>0.007318</td>
#       <td>0.003383</td>
#       <td>00:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
uploader = SimpleNamespace(data = ['/root/images/Abyssinian_102.jpg'])

# %%
img = PILImage.create('/root/images/Abyssinian_102.jpg')
img.to_thumb(192)
# Out:
# <PIL.Image.Image image mode=RGB size=192x179 at 0x7FEA431EAD90>

# %%
uploader = widgets.FileUpload()
uploader
# Out:
# FileUpload(value={}, description='Upload')

# %%
uploader = SimpleNamespace(data = ['/root/images/Abyssinian_102.jpg'])

# %%
img = PILImage.create(uploader.data[0])
is_cat,_,probs = learn.predict(img)
print(f"Is this a cat?: {is_cat}.")
print(f"Probability it's a cat: {probs[1].item():.6f}")
# Out:
# Is this a cat?: True.
# Probability it's a cat: 1.000000

# %%
# Out:
# /content
